# %% [markdown]
# <a href="https://colab.research.google.com/github/Noel1805/Inteligencia_Artificial/blob/main/Twiter_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea
# Confirmar que el análisis de agrupamiento, incluyendo el código, la ejecución y las explicaciones, se ha revisado correctamente.

# %% [markdown]
# ## Análisis de Clustering de Datos
#
# Este cuaderno realiza un análisis completo de clustering utilizando el algoritmo K-Means sobre un conjunto de datos específico. El objetivo es identificar grupos naturales dentro de los datos y evaluar la calidad de estos agrupamientos. Se enfoca en las características 'op', 'co', 'ex' y 'ag' según la solicitud del usuario.

# %% [markdown]
# ### 1. Configuración Inicial e Importación de Librerías
#
# Primero, montamos Google Drive para acceder al archivo de datos y cargamos todas las librerías necesarias para el análisis.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix
from sklearn.preprocessing import label_binarize
from sklearn.metrics import pairwise_distances
import warnings
warnings.filterwarnings('ignore') # Ignorar warnings para una salida más limpia

# %% [markdown]
# ### 2. Carga y Exploración Inicial del Dataframe
#
# Cargamos el archivo `analisis.csv` y realizamos una primera exploración para entender su estructura y contenido. Se corregirá la ruta para asegurar la lectura desde Google Drive.

# %%
# Cargar el dataframe desde Google Drive
dataframe = pd.read_csv(r"/content/drive/MyDrive/analisis.csv")

print("Primeras 5 filas del dataframe:")
display(dataframe.head())

print("\nEstadísticas descriptivas del dataframe:")
display(dataframe.describe())

print("\nCantidad de elementos por categoría:")
display(dataframe.groupby("categoria").size())

print("\nHistogramas de las características numéricas:")
dataframe.drop(columns=["categoria"]).hist(figsize=(12, 8))
plt.suptitle('Histogramas de Características Numéricas', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Primeras 5 filas del dataframe:
#            usuario         op         co         ex         ag         ne  \
# 0     3gerardpique  34.297953  28.148819  41.948819  29.370315   9.841575
# 1  aguerosergiokun  44.986842  20.525865  37.938947  24.279098  10.362406
# 2   albertochicote  41.733854  13.745417  38.999896  34.645521   8.836979
# 3    AlejandroSanz  40.377154  15.377462  52.337538  31.082154   5.032231
# 4   alfredocasero1  36.664677  19.642258  48.530806  31.138871   7.305968
#
#    wordcount  categoria
# 0    37.0945          7
# 1    78.7970          7
# 2    49.2604          4
# 3    80.4538          2
# 4    47.0645          4
# Estadísticas descriptivas del dataframe:
#                op          co          ex          ag          ne   wordcount  \
# count  140.000000  140.000000  140.000000  140.000000  140.000000  140.000000
# mean    44.414591   22.977135   40.764428   22.918528    8.000098   98.715484
# std      8.425723    5.816851    7.185246    7.657122    3.039248   44.714071
# min     30.020465    7.852756   18.693542    9.305985    1.030213    5.020800
# 25%     38.206484   19.740299   36.095722   17.050993    6.086144   66.218475
# 50%     44.507091   22.466718   41.457492   21.384554    7.839722   94.711400
# 75%     49.365923   26.091606   45.197769   28.678866    9.758189  119.707925
# max     71.696129   49.637863   59.824844   40.583162   23.978462  217.183200
#
#         categoria
# count  140.000000
# mean     4.050000
# std      2.658839
# min      1.000000
# 25%      2.000000
# 50%      3.500000
# 75%      7.000000
# max      9.000000
# Cantidad de elementos por categoría:
# categoria
# 1    27
# 2    34
# 3     9
# 4    19
# 5     4
# 6     8
# 7    17
# 8    16
# 9     6
# dtype: int64
# Histogramas de las características numéricas:

# %% [markdown]
# ### 3. Preparación de Datos para Clustering y Pairplot
#
# Seleccionamos las características solicitadas ('op', 'co', 'ex', 'ag') para el clustering y creamos los arrays `x` e `y`. Además, generamos un pairplot para visualizar las relaciones entre estas características y las categorías.

# %%
columnas = ["op","co","ex","ag"]
seleccionadas = ["op","co","ex"] # Se seleccionan 3 de las 4 columnas pedidas por el usuario para evitar la 'maldición de la dimensionalidad'

# Crear los arrays x (características) e y (etiquetas de categoría)
x = np.array(dataframe[seleccionadas])
y = np.array(dataframe["categoria"])

print(f"Características seleccionadas para el clustering: {seleccionadas}")
print(f"Shape de x (con las 3 características seleccionadas): {x.shape}")
print(f"Shape de y (etiquetas de categoría): {y.shape}")

print("\nPairplot de las características seleccionadas por categoría:")
sb.pairplot(dataframe.dropna(), hue="categoria", height=4, vars=seleccionadas, kind="scatter", palette="hsv")
plt.suptitle('Pairplot de Características Seleccionadas por Categoría', y=1.02)
plt.show()
# Out:
# Características seleccionadas para el clustering: ['op', 'co', 'ex']
# Shape de x (con las 3 características seleccionadas): (140, 3)
# Shape de y (etiquetas de categoría): (140,)
#
# Pairplot de las características seleccionadas por categoría:

# %% [markdown]
# ### 3.1. Reducción de Dimensionalidad con PCA
#
# Para combatir la 'maldición de la dimensionalidad' y encontrar componentes que mejor expliquen la varianza en los datos, aplicaremos el Análisis de Componentes Principales (PCA). Reduciremos las 4 características originales ('op', 'co', 'ex', 'ag') a 3 componentes principales. Estas componentes serán utilizadas para el clustering y las visualizaciones posteriores.

# %%
from sklearn.decomposition import PCA

# Las características originales para PCA son las 4 iniciales
columnas_pca = ["op","co","ex","ag"]
x_original = np.array(dataframe[columnas_pca])

# Crear una instancia de PCA para 3 componentes
pca = PCA(n_components=3)

# Ajustar PCA a los datos y transformar los datos
x = pca.fit_transform(x_original)

# Actualizar 'seleccionadas' para reflejar las componentes principales
seleccionadas = [f'PC{i+1}' for i in range(x.shape[1])]

print(f"Características originales usadas para PCA: {columnas_pca}")
print(f"Dimensiones después de PCA: {x.shape}")
print(f"Varianza explicada por cada componente principal: {pca.explained_variance_ratio_}")
print(f"Varianza acumulada explicada: {pca.explained_variance_ratio_.sum():.2f}")
print(f"Nuevas etiquetas de características para visualización: {seleccionadas}")
# Out:
# Características originales usadas para PCA: ['op', 'co', 'ex', 'ag']
# Dimensiones después de PCA: (140, 3)
# Varianza explicada por cada componente principal: [0.63438793 0.17118403 0.12256851]
# Varianza acumulada explicada: 0.93
# Nuevas etiquetas de características para visualización: ['PC1', 'PC2', 'PC3']

# %% [markdown]
# ### 3.2. Pairplot de los Componentes Principales por Categoría
#
# Ahora visualizamos los componentes principales, coloreados por las categorías originales, para ver cómo se distribuyen los datos en el nuevo espacio reducido.

# %%
# Crear un DataFrame temporal para el pairplot de PCA
df_pca = pd.DataFrame(data=x, columns=seleccionadas)
df_pca['categoria'] = dataframe['categoria']

sb.pairplot(df_pca.dropna(), hue="categoria", height=4, vars=seleccionadas, kind="scatter", palette="hsv")
plt.suptitle('Pairplot de Componentes Principales por Categoría', y=1.02)
plt.show()

# %% [markdown]
# ### 4. Visualización 3D Inicial de los Datos
#
# Visualizamos las primeras tres características de los datos en un gráfico 3D, coloreando los puntos según sus categorías originales para una inspección visual inicial.

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection="3d")

colores_originales = ["blue","red","green","cyan","yellow","orange","black","pink","brown","purple"]

asignar_colores_originales = []
# Ajustar el índice para que coincida con los colores si las categorías empiezan en 1
for row in y:
    if row -1 < len(colores_originales):
        asignar_colores_originales.append(colores_originales[row-1])
    else:
        asignar_colores_originales.append('gray') # Color por defecto si no hay suficiente colores

# Para la visualización 3D, se usan las primeras 3 características de las seleccionadas
ax.scatter(x[:,0], x[:,1], x[:,2], c=asignar_colores_originales, s=60, alpha=0.8)
ax.set_xlabel(seleccionadas[0].upper())
ax.set_ylabel(seleccionadas[1].upper())
ax.set_zlabel(seleccionadas[2].upper())
ax.set_title(f'Visualización 3D de {seleccionadas[0].upper()}, {seleccionadas[1].upper()} y {seleccionadas[2].upper()} (Categorías Originales)')
plt.show()

# %% [markdown]
# ### 5. Determinación del Número Óptimo de Clusters (K)
#
# Empleamos diferentes metodologías (Elbow, Silhouette, Calinski-Harabasz, Davies-Bouldin) para determinar el número óptimo de clusters (K).

# %%
k_values = list(range(1, 20))

inertia = []
silhouettes = []
calinski = []
davies = []

for i in k_values:
    km = KMeans(n_clusters=i, random_state=0, n_init=10) # n_init=10 para evitar warnings
    if i == 1:
        km.fit(x)
        inertia.append(km.inertia_)
        silhouettes.append(np.nan) # No se puede calcular Silhouette para k=1
        calinski.append(np.nan)    # No se puede calcular Calinski para k=1
        davies.append(np.nan)      # No se puede calcular Davies para k=1
    else:
        labels = km.fit_predict(x)
        inertia.append(km.inertia_)
        silhouettes.append(silhouette_score(x, labels))
        calinski.append(calinski_harabasz_score(x, labels))
        davies.append(davies_bouldin_score(x, labels))

# Encontrar los K óptimos según cada métrica
sil_best = k_values[np.nanargmax(silhouettes)] if not np.all(np.isnan(silhouettes)) else k_values[0]
cal_best = k_values[np.nanargmax(calinski)] if not np.all(np.isnan(calinski)) else k_values[0]
dav_best = k_values[np.nanargmin(davies)] if not np.all(np.isnan(davies)) else k_values[0]

# Heurística para Elbow: máximo de la segunda diferencia absoluta de la inercia
elbow_best = k_values[0]
if len(inertia) >= 3:
    second_diff = np.diff(inertia, n=2)  # Calcula la segunda derivada de la inercia
    elbow_idx = np.argmax(np.abs(second_diff)) + 1 # +1 porque diff reduce en 2, y queremos el punto 'codo'
    elbow_best = k_values[elbow_idx]

print(f"K elegido por Elbow (heurística): {elbow_best}")
print(f"K elegido por Silhouette (máx): {sil_best}")
print(f"K elegido por Calinski-Harabasz (máx): {cal_best}")
print(f"K elegido por Davies-Bouldin (mín): {dav_best}")

# Graficar cada métrica
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.ravel()

axes[0].plot(k_values, inertia, marker='o')
axes[0].set_title('Inercia (Elbow)')
axes[0].set_xlabel('K')
axes[0].set_ylabel('Inercia')
axes[0].axvline(elbow_best, color='red', linestyle='--', label=f'K óptimo = {elbow_best}')
axes[0].legend()

axes[1].plot(k_values, silhouettes, marker='o')
axes[1].set_title('Silhouette Score (Mayor es mejor)')
axes[1].set_xlabel('K')
axes[1].set_ylabel('Silhouette')
axes[1].axvline(sil_best, color='red', linestyle='--', label=f'K óptimo = {sil_best}')
axes[1].legend()

axes[2].plot(k_values, calinski, marker='o')
axes[2].set_title('Calinski-Harabasz Index (Mayor es mejor)')
axes[2].set_xlabel('K')
axes[2].set_ylabel('Calinski-Harabasz')
axes[2].axvline(cal_best, color='red', linestyle='--', label=f'K óptimo = {cal_best}')
axes[2].legend()

axes[3].plot(k_values, davies, marker='o')
axes[3].set_title('Davies-Bouldin Index (Menor es mejor)')
axes[3].set_xlabel('K')
axes[3].set_ylabel('Davies-Bouldin')
axes[3].axvline(dav_best, color='red', linestyle='--', label=f'K óptimo = {dav_best}')
axes[3].legend()

plt.tight_layout()
plt.show()
# Out:
# K elegido por Elbow (heurística): 2
# K elegido por Silhouette (máx): 2
# K elegido por Calinski-Harabasz (máx): 2
# K elegido por Davies-Bouldin (mín): 16

# %% [markdown]
# ### 6. Creación de Modelos K-Means y Centros de Cluster
#
# Se crean los modelos K-Means utilizando los valores de K determinados por cada métrica. Se imprimen los conteos de usuarios por cluster y las coordenadas de los centroides.

# %%
ks = {
    "elbow": elbow_best,
    "silhouette": sil_best,
    "calinski": cal_best,
    "davies": dav_best
}

models = {}
colores = ["blue","red","green","cyan","yellow","orange","black","pink","brown","purple", "magenta", "lime", "teal", "navy", "maroon", "olive", "coral", "gold", "silver", "violet", "indigo", "turquoise", "salmon", "plum", "orchid", "tan", "lavender", "beige", "peach", "mint", "apricol", "charcoal", "ivory"]

for name, k in ks.items():
    km = KMeans(n_clusters=int(k), random_state=0, n_init=10).fit(x)
    models[name] = km
    labels = km.labels_
    counts = np.bincount(labels, minlength=km.n_clusters)
    print(f"\n{'='*80}")
    print(f"MODELO: {name.upper()} (k={k})")
    print(f"{'='*80}")
    print(f"  Conteo de usuarios por cluster: {counts}")
    print(f"  Centroides:\n{km.cluster_centers_}")
# Out:
# ================================================================================
# MODELO: ELBOW (k=2)
# ================================================================================
#   Conteo de usuarios por cluster: [58 82]
#   Centroides:
# [[-11.59727788   0.0435036   -0.67223114]
#  [  8.20295265  -0.03077084   0.47548056]]
#
# ================================================================================
# MODELO: SILHOUETTE (k=2)
# ================================================================================
#   Conteo de usuarios por cluster: [58 82]
#   Centroides:
# [[-11.59727788   0.0435036   -0.67223114]
#  [  8.20295265  -0.03077084   0.47548056]]
#
# ================================================================================
# MODELO: CALINSKI (k=2)
# ================================================================================
#   Conteo de usuarios por cluster: [58 82]
#   Centroides:
# [[-11.59727788   0.0435036   -0.67223114]
#  [  8.20295265  -0.03077084   0.47548056]]
#
# ================================================================================
# MODELO: DAVIES (k=16)
# ================================================================================
#   Conteo de usuarios por cluster: [ 8 13 17  6  3  3  5 13  8  9 11  3  6 18  3 14]
#   Centroides:
# [[ -9.34036772   2.7498558   -4.68328709]
#  [ 12.56960533  -3.30224607  -1.51027897]
#  [  5.88628051  -7.00066611   3.90516069]
#  [-21.83672695  -4.24419769   4.73759648]
#  [ -0.84383385   7.07229424  12.04402966]
#  [ 15.00645399  18.03025792   6.23335264]
#  [ 23.96737515  -7.19159368  -8.70728924]
#  [  5.22807114   3.94643258   3.79565539]
#  [-10.54016858  -7.31226875  -0.74448543]
#  [-19.15631336   1.65105136  -5.53924861]
#  [-12.54969454   0.22894586   1.37458508]
#  [ -5.89588855   9.91944775 -10.72077055]
#  [ 14.44662799   4.15448323   1.66139646]
#  [ -2.84038295   1.56649948   2.08323346]
#  [  7.85335155   9.84092472  -8.51633298]
#  [  4.66653924   0.24777335  -3.38708524]]

# %% [markdown]
# ### 7. Visualización 3D de los Clusters y Centroides
#
# Graficamos los clusters y sus centroides en 3D para cada modelo. Se utilizan las primeras tres características de las seleccionadas.

# %%
fig = plt.figure(figsize=(16, 12))

for i, (name, km) in enumerate(models.items(), start=1):
    ax = fig.add_subplot(2, 2, i, projection="3d")
    labels = km.predict(x)

    asignar = [colores[l] if l < len(colores) else "gray" for l in labels]
    C = km.cluster_centers_

    ax.scatter(x[:,0], x[:,1], x[:,2], c=asignar, s=40, alpha=0.7)
    ax.scatter(C[:,0], C[:,1], C[:,2], marker="*", c=colores[:km.n_clusters], s=200, edgecolor="k")
    ax.set_title(f"{name.upper()} (k={km.n_clusters}) - ({seleccionadas[0].upper()}, {seleccionadas[1].upper()}, {seleccionadas[2].upper()})")
    ax.set_xlabel(seleccionadas[0].upper())
    ax.set_ylabel(seleccionadas[1].upper())
    ax.set_zlabel(seleccionadas[2].upper())

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. Visualización 2D de los Clusters y Centroides
#
# Graficamos los clusters y sus centroides en proyecciones 2D para cada modelo (pares de las primeras tres características).

# %%
# Se toman las primeras tres características de las seleccionadas para los gráficos 2D
f1_name, f2_name, f3_name = seleccionadas[0], seleccionadas[1], seleccionadas[2]
f1 = x[:, 0] # PC1 from x array
f2 = x[:, 1] # PC2 from x array
f3 = x[:, 2] # PC3 from x array

for name, km in models.items():
    labels = km.predict(x)
    asignar = [colores[l] if l < len(colores) else "gray" for l in labels]
    C = km.cluster_centers_

    fig, axs = plt.subplots(1, 3, figsize=(18, 5))

    # feature 0 vs 1
    axs[0].scatter(f1, f2, c=asignar[:len(f1)], s=70, alpha=0.7)
    axs[0].scatter(C[:,0], C[:,1], marker="*", c=colores[:km.n_clusters], s=200, edgecolor="k")
    axs[0].set_xlabel(f1_name.upper()); axs[0].set_ylabel(f2_name.upper())
    axs[0].set_title(f"{name.upper()} - {f1_name.upper()} vs {f2_name.upper()} (k={km.n_clusters})")

    # feature 0 vs 2
    axs[1].scatter(f1, f3, c=asignar[:len(f1)], s=70, alpha=0.7)
    axs[1].scatter(C[:,0], C[:,2], marker="*", c=colores[:km.n_clusters], s=200, edgecolor="k")
    axs[1].set_xlabel(f1_name.upper()); axs[1].set_ylabel(f3_name.upper())
    axs[1].set_title(f"{name.upper()} - {f1_name.upper()} vs {f3_name.upper()} (k={km.n_clusters})")

    # feature 1 vs 2
    axs[2].scatter(f2, f3, c=asignar[:len(f2)], s=70, alpha=0.7)
    axs[2].scatter(C[:,1], C[:,2], marker="*", c=colores[:km.n_clusters], s=200, edgecolor="k")
    axs[2].set_xlabel(f2_name.upper()); axs[2].set_ylabel(f3_name.upper())
    axs[2].set_title(f"{name.upper()} - {f2_name.upper()} vs {f3_name.upper()} (k={km.n_clusters})")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 9. Análisis de Cantidad y Diversidad de Categorías por Cluster
#
# Calculamos cuántos usuarios hay en cada cluster y analizamos la diversidad de categorías (profesiones) presentes en cada uno.

# %%
for name, km in models.items():
    labels = km.predict(x)

    # Crear DataFrame con usuario, categoría y label del cluster
    copy = pd.DataFrame()
    copy["usuario"] = dataframe["usuario"].values
    copy["categoria"] = dataframe["categoria"].values
    copy["label"] = labels

    # Cantidad de usuarios por cluster
    print(f"\n{'='*60}")
    print(f"Modelo: {name.upper()} (k={km.n_clusters})")
    print(f"{'='*60}")
    print("\nCantidad de usuarios por cluster:")
    cantidadGrupo = pd.DataFrame()
    cantidadGrupo["Color"] = colores[:km.n_clusters]
    cantidadGrupo["Cluster"] = range(km.n_clusters)
    cantidadGrupo["Cantidad"] = [np.sum(labels == i) for i in range(km.n_clusters)]
    print(cantidadGrupo.to_string(index=False))

    # Diversidad de categorías por cada cluster
    print(f"\nDiversidad de categorías por cluster:")
    for cluster_id in range(km.n_clusters):
        cluster_data = copy[copy["label"] == cluster_id]
        categoria_counts = cluster_data.groupby("categoria").size()
        print(f"\n  Cluster {cluster_id} ({colores[cluster_id]}):")
        print(f"    {dict(categoria_counts)}")
# Out:
# ============================================================
# Modelo: ELBOW (k=2)
# ============================================================
#
# Cantidad de usuarios por cluster:
# Color  Cluster  Cantidad
#  blue        0        58
#   red        1        82
#
# Diversidad de categorías por cluster:
#
#   Cluster 0 (blue):
#     {1: np.int64(5), 2: np.int64(7), 3: np.int64(1), 4: np.int64(13), 5: np.int64(3), 6: np.int64(4), 7: np.int64(11), 8: np.int64(10), 9: np.int64(4)}
#
#   Cluster 1 (red):
#     {1: np.int64(22), 2: np.int64(27), 3: np.int64(8), 4: np.int64(6), 5: np.int64(1), 6: np.int64(4), 7: np.int64(6), 8: np.int64(6), 9: np.int64(2)}
#
# ============================================================
# Modelo: SILHOUETTE (k=2)
# ============================================================
#
# Cantidad de usuarios por cluster:
# Color  Cluster  Cantidad
#  blue        0        58
#   red        1        82
#
# Diversidad de categorías por cluster:
#
#   Cluster 0 (blue):
#     {1: np.int64(5), 2: np.int64(7), 3: np.int64(1), 4: np.int64(13), 5: np.int64(3), 6: np.int64(4), 7: np.int64(11), 8: np.int64(10), 9: np.int64(4)}
#
#   Cluster 1 (red):
#     {1: np.int64(22), 2: np.int64(27), 3: np.int64(8), 4: np.int64(6), 5: np.int64(1), 6: np.int64(4), 7: np.int64(6), 8: np.int64(6), 9: np.int64(2)}
#
# ============================================================
# Modelo: CALINSKI (k=2)
# ============================================================
#
# Cantidad de usuarios por cluster:
# Color  Cluster  Cantidad
#  blue        0        58
#   red        1        82
#
# Diversidad de categorías por cluster:
#
#   Cluster 0 (blue):
#     {1: np.int64(5), 2: np.int64(7), 3: np.int64(1), 4: np.int64(13), 5: np.int64(3), 6: np.int64(4), 7: np.int64(11), 8: np.int64(10), 9: np.int64(4)}
#
#   Cluster 1 (red):
#     {1: np.int64(22), 2: np.int64(27), 3: np.int64(8), 4: np.int64(6), 5: np.int64(1), 6: np.int64(4), 7: np.int64(6), 8: np.int64(6), 9: np.int64(2)}
#
# ============================================================
# Modelo: DAVIES (k=16)
# ============================================================
#
# Cantidad de usuarios por cluster:
#   Color  Cluster  Cantidad
#    blue        0         8
#     red        1        13
#   green        2        17
#    cyan        3         6
#  yellow        4         3
#  orange        5         3
#   black        6         5
#    pink        7        13
#   brown        8         8
#  purple        9         9
# magenta       10        11
#    lime       11         3
#    teal       12         6
#    navy       13        18
#  maroon       14         3
#   olive       15        14
#
# Diversidad de categorías por cluster:
#
#   Cluster 0 (blue):
#     {1: np.int64(2), 4: np.int64(2), 7: np.int64(2), 8: np.int64(1), 9: np.int64(1)}
#
#   Cluster 1 (red):
#     {1: np.int64(3), 2: np.int64(5), 3: np.int64(2), 4: np.int64(2), 7: np.int64(1)}
#
#   Cluster 2 (green):
#     {1: np.int64(4), 2: np.int64(7), 3: np.int64(3), 4: np.int64(2), 6: np.int64(1)}
#
#   Cluster 3 (cyan):
#     {2: np.int64(1), 4: np.int64(3), 5: np.int64(1), 7: np.int64(1)}
#
#   Cluster 4 (yellow):
#     {7: np.int64(2), 8: np.int64(1)}
#
#   Cluster 5 (orange):
#     {1: np.int64(1), 8: np.int64(2)}
#
#   Cluster 6 (black):
#     {1: np.int64(1), 2: np.int64(4)}
#
#   Cluster 7 (pink):
#     {1: np.int64(3), 2: np.int64(3), 3: np.int64(1), 6: np.int64(1), 7: np.int64(2), 8: np.int64(2), 9: np.int64(1)}
#
#   Cluster 8 (brown):
#     {2: np.int64(4), 4: np.int64(3), 9: np.int64(1)}
#
#   Cluster 9 (purple):
#     {1: np.int64(2), 4: np.int64(2), 5: np.int64(2), 7: np.int64(2), 9: np.int64(1)}
#
#   Cluster 10 (magenta):
#     {1: np.int64(1), 2: np.int64(2), 4: np.int64(3), 6: np.int64(1), 7: np.int64(2), 8: np.int64(2)}
#
#   Cluster 11 (lime):
#     {7: np.int64(1), 8: np.int64(2)}
#
#   Cluster 12 (teal):
#     {1: np.int64(2), 2: np.int64(4)}
#
#   Cluster 13 (navy):
#     {1: np.int64(2), 3: np.int64(1), 4: np.int64(1), 6: np.int64(4), 7: np.int64(3), 8: np.int64(5), 9: np.int64(2)}
#
#   Cluster 14 (maroon):
#     {1: np.int64(1), 3: np.int64(1), 6: np.int64(1)}
#
#   Cluster 15 (olive):
#     {1: np.int64(5), 2: np.int64(4), 3: np.int64(1), 4: np.int64(1), 5: np.int64(1), 7: np.int64(1), 8: np.int64(1)}

# %% [markdown]
# ### 10. Distribución Detallada de Profesiones por Cluster
#
# Se analiza en detalle la composición de cada cluster en términos de categorías de usuario (profesiones), mostrando el porcentaje y listando los usuarios.

# %%
categorias_nombres = {
    1: "Actor/Actriz",
    2: "Cantante",
    3: "Modelo",
    4: "TV, Series",
    5: "Radio",
    6: "Tecnologia",
    7: "Deportes",
    8: "Politica",
    9: "Escritores",
    0: "Ninguno" # Asumimos que 0 podría ser una categoría 'ninguno' o un error
}

for name, km in models.items():
    labels = km.predict(x)

    print(f"\n{'='*80}")
    print(f"MODELO: {name.upper()} (k={km.n_clusters})")
    print(f"{'='*80}")

    # Por cada cluster, mostrar la diversidad de categorías
    for cluster_id in range(km.n_clusters):
        cluster_index = labels == cluster_id
        cluster_data = dataframe[cluster_index]

        # Contar categorías en este cluster
        categoria_counts = cluster_data["categoria"].value_counts().sort_index()

        print(f"\n{'─'*80}")
        print(f"Cluster {cluster_id} ({colores[cluster_id]}) - Total usuarios: {len(cluster_data)}")
        print(f"{'─'*80}")

        # Mostrar distribución de categorías
        for cat_id, count in categoria_counts.items():
            porcentaje = (count / len(cluster_data)) * 100
            cat_name = categorias_nombres.get(cat_id, "Desconocida")
            print(f"  {cat_name:20s} ({cat_id}): {count:3d} usuarios ({porcentaje:5.1f}%)")

        # Mostrar usuarios en este cluster
        print(f"\n  Usuarios en cluster {cluster_id}:")
        usuarios_cluster = cluster_data[["usuario", "categoria"]].copy()
        usuarios_cluster["categoria_nombre"] = usuarios_cluster["categoria"].map(categorias_nombres)
        for idx, row in usuarios_cluster.iterrows():
            print(f"    - {row['usuario']:25s} ({row['categoria_nombre']})")
# Out:
# ================================================================================
# MODELO: ELBOW (k=2)
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 0 (blue) - Total usuarios: 58
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   5 usuarios (  8.6%)
#   Cantante             (2):   7 usuarios ( 12.1%)
#   Modelo               (3):   1 usuarios (  1.7%)
#   TV, Series           (4):  13 usuarios ( 22.4%)
#   Radio                (5):   3 usuarios (  5.2%)
#   Tecnologia           (6):   4 usuarios (  6.9%)
#   Deportes             (7):  11 usuarios ( 19.0%)
#   Politica             (8):  10 usuarios ( 17.2%)
#   Escritores           (9):   4 usuarios (  6.9%)
#
#   Usuarios en cluster 0:
#     - 3gerardpique              (Deportes)
#     - albertochicote            (TV, Series)
#     - AlejandroSanz             (Cantante)
#     - alfredocasero1            (TV, Series)
#     - alo_oficial               (Deportes)
#     - andresiniesta8            (Deportes)
#     - andykusnetzoff            (Radio)
#     - andy_murray               (Deportes)
#     - BarackObama               (Politica)
#     - Berto_Romero              (TV, Series)
#     - Buenafuente               (TV, Series)
#     - CarlosAuryn               (Cantante)
#     - CasillasWorld             (Deportes)
#     - CFKArgentina              (Politica)
#     - charliesheen              (Actor/Actriz)
#     - ChristianG_7              (TV, Series)
#     - CristiPedroche            (TV, Series)
#     - DaniMateoAgain            (Radio)
#     - DANIROVIRA                (Actor/Actriz)
#     - davidbisbal               (Cantante)
#     - David_Busta               (Cantante)
#     - DidacLee                  (Tecnologia)
#     - drexlerjorge              (Cantante)
#     - edans                     (Tecnologia)
#     - EdwardNorton              (Actor/Actriz)
#     - eva_hache                 (Actor/Actriz)
#     - FALCAO                    (Deportes)
#     - FernandezAnibal           (Politica)
#     - fieritacatalano           (Tecnologia)
#     - GeorgeHWBush              (Politica)
#     - HerreraBeutler            (Politica)
#     - ierrejon                  (Politica)
#     - iescolar                  (Escritores)
#     - JesusCalleja              (TV, Series)
#     - JesusEncinar              (Tecnologia)
#     - JohnKerry                 (Politica)
#     - jordievole                (TV, Series)
#     - jordiGlez                 (TV, Series)
#     - josjaviersantos           (Escritores)
#     - JPVarsky                  (Radio)
#     - KAKA                      (Deportes)
#     - KateUpton                 (Modelo)
#     - lorenzo99                 (Deportes)
#     - manuginobili              (Deportes)
#     - maria_patino              (TV, Series)
#     - NadalMiki                 (TV, Series)
#     - pabloalboran              (Cantante)
#     - Pablo_Iglesias_           (Politica)
#     - perezreverte              (Escritores)
#     - pnique                    (Politica)
#     - porliniers                (Escritores)
#     - RafaelNadal               (Deportes)
#     - ristomejide               (TV, Series)
#     - sanchezcastejon           (Politica)
#     - SerranoIsmael             (Cantante)
#     - XabiAlonso                (Deportes)
#     - XaviRodriguez             (TV, Series)
#     - _josecoronado_            (Actor/Actriz)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 1 (red) - Total usuarios: 82
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):  22 usuarios ( 26.8%)
#   Cantante             (2):  27 usuarios ( 32.9%)
#   Modelo               (3):   8 usuarios (  9.8%)
#   TV, Series           (4):   6 usuarios (  7.3%)
#   Radio                (5):   1 usuarios (  1.2%)
#   Tecnologia           (6):   4 usuarios (  4.9%)
#   Deportes             (7):   6 usuarios (  7.3%)
#   Politica             (8):   6 usuarios (  7.3%)
#   Escritores           (9):   2 usuarios (  2.4%)
#
#   Usuarios en cluster 1:
#     - aguerosergiokun           (Deportes)
#     - andyroddick               (Deportes)
#     - AngelAlessandra           (Modelo)
#     - antoniobanderas           (Actor/Actriz)
#     - aplusk                    (Actor/Actriz)
#     - AvrilLavigne              (Cantante)
#     - BarRefaeli                (Modelo)
#     - BillGates                 (Tecnologia)
#     - britneyspears             (Cantante)
#     - carmenelectra             (Modelo)
#     - Carrie_Br4dshaw           (Modelo)
#     - celinedion                (Cantante)
#     - cesarmillan               (TV, Series)
#     - CindyCrawford             (Modelo)
#     - Clyburn                   (Politica)
#     - CourteneyCox              (Actor/Actriz)
#     - Courtney                  (Cantante)
#     - Cristiano                 (Deportes)
#     - Diane_Keaton              (Actor/Actriz)
#     - EmWatson                  (Actor/Actriz)
#     - enrique305                (Cantante)
#     - epunset                   (Tecnologia)
#     - EvaLongoria               (Modelo)
#     - Fergie                    (Cantante)
#     - foofighters               (Cantante)
#     - gwenstefani               (Cantante)
#     - GwynethPaltrow            (Actor/Actriz)
#     - heidiklum                 (Modelo)
#     - HilaryDuff                (Cantante)
#     - HillaryClinton            (Politica)
#     - hughlaurie                (TV, Series)
#     - IamStevenT                (Cantante)
#     - IanMcKellen               (Actor/Actriz)
#     - JerrySeinfeld             (Actor/Actriz)
#     - jessicaalba               (Actor/Actriz)
#     - JessieJ                   (Cantante)
#     - jiminhofe                 (Politica)
#     - jimlangevin               (Politica)
#     - jimmyfallon               (TV, Series)
#     - jk_rowling                (Escritores)
#     - JLo                       (Cantante)
#     - jtimberlake               (Cantante)
#     - JudgeJudy                 (TV, Series)
#     - justdemi                  (Actor/Actriz)
#     - justinbieber              (Cantante)
#     - kanyewest                 (Cantante)
#     - katyperry                 (Cantante)
#     - KevinSpacey               (Actor/Actriz)
#     - KidRock                   (Cantante)
#     - kobebryant                (Deportes)
#     - ladygaga                  (Cantante)
#     - LennyKravitz              (Cantante)
#     - LeoDiCaprio               (Actor/Actriz)
#     - MariahCarey               (Cantante)
#     - martinvars                (Tecnologia)
#     - MeganFox516               (Actor/Actriz)
#     - MelanieGriffith           (Actor/Actriz)
#     - MileyCyrus                (Actor/Actriz)
#     - OfficialAdele             (Cantante)
#     - Oprah                     (TV, Series)
#     - paugasol                  (Deportes)
#     - PaulaMeliveo              (Radio)
#     - paulocoelho               (Escritores)
#     - RealHughJackman           (Actor/Actriz)
#     - Rep_Hunter                (Politica)
#     - rihanna                   (Cantante)
#     - SarahPalinUSA             (Politica)
#     - shakira                   (Cantante)
#     - SJP                       (Actor/Actriz)
#     - springsteen               (Cantante)
#     - SSantiagosegura           (Actor/Actriz)
#     - stevewoz                  (Tecnologia)
#     - taylorswift13             (Cantante)
#     - TheEllenShow              (TV, Series)
#     - thelittleidiot            (Cantante)
#     - TheReal_Jlh               (Actor/Actriz)
#     - TomCruise                 (Actor/Actriz)
#     - tomhanks                  (Actor/Actriz)
#     - usainbolt                 (Deportes)
#     - victoriabeckham           (Modelo)
#     - xoellopez                 (Cantante)
#     - ZacEfron                  (Actor/Actriz)
#
# ================================================================================
# MODELO: SILHOUETTE (k=2)
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 0 (blue) - Total usuarios: 58
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   5 usuarios (  8.6%)
#   Cantante             (2):   7 usuarios ( 12.1%)
#   Modelo               (3):   1 usuarios (  1.7%)
#   TV, Series           (4):  13 usuarios ( 22.4%)
#   Radio                (5):   3 usuarios (  5.2%)
#   Tecnologia           (6):   4 usuarios (  6.9%)
#   Deportes             (7):  11 usuarios ( 19.0%)
#   Politica             (8):  10 usuarios ( 17.2%)
#   Escritores           (9):   4 usuarios (  6.9%)
#
#   Usuarios en cluster 0:
#     - 3gerardpique              (Deportes)
#     - albertochicote            (TV, Series)
#     - AlejandroSanz             (Cantante)
#     - alfredocasero1            (TV, Series)
#     - alo_oficial               (Deportes)
#     - andresiniesta8            (Deportes)
#     - andykusnetzoff            (Radio)
#     - andy_murray               (Deportes)
#     - BarackObama               (Politica)
#     - Berto_Romero              (TV, Series)
#     - Buenafuente               (TV, Series)
#     - CarlosAuryn               (Cantante)
#     - CasillasWorld             (Deportes)
#     - CFKArgentina              (Politica)
#     - charliesheen              (Actor/Actriz)
#     - ChristianG_7              (TV, Series)
#     - CristiPedroche            (TV, Series)
#     - DaniMateoAgain            (Radio)
#     - DANIROVIRA                (Actor/Actriz)
#     - davidbisbal               (Cantante)
#     - David_Busta               (Cantante)
#     - DidacLee                  (Tecnologia)
#     - drexlerjorge              (Cantante)
#     - edans                     (Tecnologia)
#     - EdwardNorton              (Actor/Actriz)
#     - eva_hache                 (Actor/Actriz)
#     - FALCAO                    (Deportes)
#     - FernandezAnibal           (Politica)
#     - fieritacatalano           (Tecnologia)
#     - GeorgeHWBush              (Politica)
#     - HerreraBeutler            (Politica)
#     - ierrejon                  (Politica)
#     - iescolar                  (Escritores)
#     - JesusCalleja              (TV, Series)
#     - JesusEncinar              (Tecnologia)
#     - JohnKerry                 (Politica)
#     - jordievole                (TV, Series)
#     - jordiGlez                 (TV, Series)
#     - josjaviersantos           (Escritores)
#     - JPVarsky                  (Radio)
#     - KAKA                      (Deportes)
#     - KateUpton                 (Modelo)
#     - lorenzo99                 (Deportes)
#     - manuginobili              (Deportes)
#     - maria_patino              (TV, Series)
#     - NadalMiki                 (TV, Series)
#     - pabloalboran              (Cantante)
#     - Pablo_Iglesias_           (Politica)
#     - perezreverte              (Escritores)
#     - pnique                    (Politica)
#     - porliniers                (Escritores)
#     - RafaelNadal               (Deportes)
#     - ristomejide               (TV, Series)
#     - sanchezcastejon           (Politica)
#     - SerranoIsmael             (Cantante)
#     - XabiAlonso                (Deportes)
#     - XaviRodriguez             (TV, Series)
#     - _josecoronado_            (Actor/Actriz)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 1 (red) - Total usuarios: 82
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):  22 usuarios ( 26.8%)
#   Cantante             (2):  27 usuarios ( 32.9%)
#   Modelo               (3):   8 usuarios (  9.8%)
#   TV, Series           (4):   6 usuarios (  7.3%)
#   Radio                (5):   1 usuarios (  1.2%)
#   Tecnologia           (6):   4 usuarios (  4.9%)
#   Deportes             (7):   6 usuarios (  7.3%)
#   Politica             (8):   6 usuarios (  7.3%)
#   Escritores           (9):   2 usuarios (  2.4%)
#
#   Usuarios en cluster 1:
#     - aguerosergiokun           (Deportes)
#     - andyroddick               (Deportes)
#     - AngelAlessandra           (Modelo)
#     - antoniobanderas           (Actor/Actriz)
#     - aplusk                    (Actor/Actriz)
#     - AvrilLavigne              (Cantante)
#     - BarRefaeli                (Modelo)
#     - BillGates                 (Tecnologia)
#     - britneyspears             (Cantante)
#     - carmenelectra             (Modelo)
#     - Carrie_Br4dshaw           (Modelo)
#     - celinedion                (Cantante)
#     - cesarmillan               (TV, Series)
#     - CindyCrawford             (Modelo)
#     - Clyburn                   (Politica)
#     - CourteneyCox              (Actor/Actriz)
#     - Courtney                  (Cantante)
#     - Cristiano                 (Deportes)
#     - Diane_Keaton              (Actor/Actriz)
#     - EmWatson                  (Actor/Actriz)
#     - enrique305                (Cantante)
#     - epunset                   (Tecnologia)
#     - EvaLongoria               (Modelo)
#     - Fergie                    (Cantante)
#     - foofighters               (Cantante)
#     - gwenstefani               (Cantante)
#     - GwynethPaltrow            (Actor/Actriz)
#     - heidiklum                 (Modelo)
#     - HilaryDuff                (Cantante)
#     - HillaryClinton            (Politica)
#     - hughlaurie                (TV, Series)
#     - IamStevenT                (Cantante)
#     - IanMcKellen               (Actor/Actriz)
#     - JerrySeinfeld             (Actor/Actriz)
#     - jessicaalba               (Actor/Actriz)
#     - JessieJ                   (Cantante)
#     - jiminhofe                 (Politica)
#     - jimlangevin               (Politica)
#     - jimmyfallon               (TV, Series)
#     - jk_rowling                (Escritores)
#     - JLo                       (Cantante)
#     - jtimberlake               (Cantante)
#     - JudgeJudy                 (TV, Series)
#     - justdemi                  (Actor/Actriz)
#     - justinbieber              (Cantante)
#     - kanyewest                 (Cantante)
#     - katyperry                 (Cantante)
#     - KevinSpacey               (Actor/Actriz)
#     - KidRock                   (Cantante)
#     - kobebryant                (Deportes)
#     - ladygaga                  (Cantante)
#     - LennyKravitz              (Cantante)
#     - LeoDiCaprio               (Actor/Actriz)
#     - MariahCarey               (Cantante)
#     - martinvars                (Tecnologia)
#     - MeganFox516               (Actor/Actriz)
#     - MelanieGriffith           (Actor/Actriz)
#     - MileyCyrus                (Actor/Actriz)
#     - OfficialAdele             (Cantante)
#     - Oprah                     (TV, Series)
#     - paugasol                  (Deportes)
#     - PaulaMeliveo              (Radio)
#     - paulocoelho               (Escritores)
#     - RealHughJackman           (Actor/Actriz)
#     - Rep_Hunter                (Politica)
#     - rihanna                   (Cantante)
#     - SarahPalinUSA             (Politica)
#     - shakira                   (Cantante)
#     - SJP                       (Actor/Actriz)
#     - springsteen               (Cantante)
#     - SSantiagosegura           (Actor/Actriz)
#     - stevewoz                  (Tecnologia)
#     - taylorswift13             (Cantante)
#     - TheEllenShow              (TV, Series)
#     - thelittleidiot            (Cantante)
#     - TheReal_Jlh               (Actor/Actriz)
#     - TomCruise                 (Actor/Actriz)
#     - tomhanks                  (Actor/Actriz)
#     - usainbolt                 (Deportes)
#     - victoriabeckham           (Modelo)
#     - xoellopez                 (Cantante)
#     - ZacEfron                  (Actor/Actriz)
#
# ================================================================================
# MODELO: CALINSKI (k=2)
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 0 (blue) - Total usuarios: 58
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   5 usuarios (  8.6%)
#   Cantante             (2):   7 usuarios ( 12.1%)
#   Modelo               (3):   1 usuarios (  1.7%)
#   TV, Series           (4):  13 usuarios ( 22.4%)
#   Radio                (5):   3 usuarios (  5.2%)
#   Tecnologia           (6):   4 usuarios (  6.9%)
#   Deportes             (7):  11 usuarios ( 19.0%)
#   Politica             (8):  10 usuarios ( 17.2%)
#   Escritores           (9):   4 usuarios (  6.9%)
#
#   Usuarios en cluster 0:
#     - 3gerardpique              (Deportes)
#     - albertochicote            (TV, Series)
#     - AlejandroSanz             (Cantante)
#     - alfredocasero1            (TV, Series)
#     - alo_oficial               (Deportes)
#     - andresiniesta8            (Deportes)
#     - andykusnetzoff            (Radio)
#     - andy_murray               (Deportes)
#     - BarackObama               (Politica)
#     - Berto_Romero              (TV, Series)
#     - Buenafuente               (TV, Series)
#     - CarlosAuryn               (Cantante)
#     - CasillasWorld             (Deportes)
#     - CFKArgentina              (Politica)
#     - charliesheen              (Actor/Actriz)
#     - ChristianG_7              (TV, Series)
#     - CristiPedroche            (TV, Series)
#     - DaniMateoAgain            (Radio)
#     - DANIROVIRA                (Actor/Actriz)
#     - davidbisbal               (Cantante)
#     - David_Busta               (Cantante)
#     - DidacLee                  (Tecnologia)
#     - drexlerjorge              (Cantante)
#     - edans                     (Tecnologia)
#     - EdwardNorton              (Actor/Actriz)
#     - eva_hache                 (Actor/Actriz)
#     - FALCAO                    (Deportes)
#     - FernandezAnibal           (Politica)
#     - fieritacatalano           (Tecnologia)
#     - GeorgeHWBush              (Politica)
#     - HerreraBeutler            (Politica)
#     - ierrejon                  (Politica)
#     - iescolar                  (Escritores)
#     - JesusCalleja              (TV, Series)
#     - JesusEncinar              (Tecnologia)
#     - JohnKerry                 (Politica)
#     - jordievole                (TV, Series)
#     - jordiGlez                 (TV, Series)
#     - josjaviersantos           (Escritores)
#     - JPVarsky                  (Radio)
#     - KAKA                      (Deportes)
#     - KateUpton                 (Modelo)
#     - lorenzo99                 (Deportes)
#     - manuginobili              (Deportes)
#     - maria_patino              (TV, Series)
#     - NadalMiki                 (TV, Series)
#     - pabloalboran              (Cantante)
#     - Pablo_Iglesias_           (Politica)
#     - perezreverte              (Escritores)
#     - pnique                    (Politica)
#     - porliniers                (Escritores)
#     - RafaelNadal               (Deportes)
#     - ristomejide               (TV, Series)
#     - sanchezcastejon           (Politica)
#     - SerranoIsmael             (Cantante)
#     - XabiAlonso                (Deportes)
#     - XaviRodriguez             (TV, Series)
#     - _josecoronado_            (Actor/Actriz)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 1 (red) - Total usuarios: 82
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):  22 usuarios ( 26.8%)
#   Cantante             (2):  27 usuarios ( 32.9%)
#   Modelo               (3):   8 usuarios (  9.8%)
#   TV, Series           (4):   6 usuarios (  7.3%)
#   Radio                (5):   1 usuarios (  1.2%)
#   Tecnologia           (6):   4 usuarios (  4.9%)
#   Deportes             (7):   6 usuarios (  7.3%)
#   Politica             (8):   6 usuarios (  7.3%)
#   Escritores           (9):   2 usuarios (  2.4%)
#
#   Usuarios en cluster 1:
#     - aguerosergiokun           (Deportes)
#     - andyroddick               (Deportes)
#     - AngelAlessandra           (Modelo)
#     - antoniobanderas           (Actor/Actriz)
#     - aplusk                    (Actor/Actriz)
#     - AvrilLavigne              (Cantante)
#     - BarRefaeli                (Modelo)
#     - BillGates                 (Tecnologia)
#     - britneyspears             (Cantante)
#     - carmenelectra             (Modelo)
#     - Carrie_Br4dshaw           (Modelo)
#     - celinedion                (Cantante)
#     - cesarmillan               (TV, Series)
#     - CindyCrawford             (Modelo)
#     - Clyburn                   (Politica)
#     - CourteneyCox              (Actor/Actriz)
#     - Courtney                  (Cantante)
#     - Cristiano                 (Deportes)
#     - Diane_Keaton              (Actor/Actriz)
#     - EmWatson                  (Actor/Actriz)
#     - enrique305                (Cantante)
#     - epunset                   (Tecnologia)
#     - EvaLongoria               (Modelo)
#     - Fergie                    (Cantante)
#     - foofighters               (Cantante)
#     - gwenstefani               (Cantante)
#     - GwynethPaltrow            (Actor/Actriz)
#     - heidiklum                 (Modelo)
#     - HilaryDuff                (Cantante)
#     - HillaryClinton            (Politica)
#     - hughlaurie                (TV, Series)
#     - IamStevenT                (Cantante)
#     - IanMcKellen               (Actor/Actriz)
#     - JerrySeinfeld             (Actor/Actriz)
#     - jessicaalba               (Actor/Actriz)
#     - JessieJ                   (Cantante)
#     - jiminhofe                 (Politica)
#     - jimlangevin               (Politica)
#     - jimmyfallon               (TV, Series)
#     - jk_rowling                (Escritores)
#     - JLo                       (Cantante)
#     - jtimberlake               (Cantante)
#     - JudgeJudy                 (TV, Series)
#     - justdemi                  (Actor/Actriz)
#     - justinbieber              (Cantante)
#     - kanyewest                 (Cantante)
#     - katyperry                 (Cantante)
#     - KevinSpacey               (Actor/Actriz)
#     - KidRock                   (Cantante)
#     - kobebryant                (Deportes)
#     - ladygaga                  (Cantante)
#     - LennyKravitz              (Cantante)
#     - LeoDiCaprio               (Actor/Actriz)
#     - MariahCarey               (Cantante)
#     - martinvars                (Tecnologia)
#     - MeganFox516               (Actor/Actriz)
#     - MelanieGriffith           (Actor/Actriz)
#     - MileyCyrus                (Actor/Actriz)
#     - OfficialAdele             (Cantante)
#     - Oprah                     (TV, Series)
#     - paugasol                  (Deportes)
#     - PaulaMeliveo              (Radio)
#     - paulocoelho               (Escritores)
#     - RealHughJackman           (Actor/Actriz)
#     - Rep_Hunter                (Politica)
#     - rihanna                   (Cantante)
#     - SarahPalinUSA             (Politica)
#     - shakira                   (Cantante)
#     - SJP                       (Actor/Actriz)
#     - springsteen               (Cantante)
#     - SSantiagosegura           (Actor/Actriz)
#     - stevewoz                  (Tecnologia)
#     - taylorswift13             (Cantante)
#     - TheEllenShow              (TV, Series)
#     - thelittleidiot            (Cantante)
#     - TheReal_Jlh               (Actor/Actriz)
#     - TomCruise                 (Actor/Actriz)
#     - tomhanks                  (Actor/Actriz)
#     - usainbolt                 (Deportes)
#     - victoriabeckham           (Modelo)
#     - xoellopez                 (Cantante)
#     - ZacEfron                  (Actor/Actriz)
#
# ================================================================================
# MODELO: DAVIES (k=16)
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 0 (blue) - Total usuarios: 8
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   2 usuarios ( 25.0%)
#   TV, Series           (4):   2 usuarios ( 25.0%)
#   Deportes             (7):   2 usuarios ( 25.0%)
#   Politica             (8):   1 usuarios ( 12.5%)
#   Escritores           (9):   1 usuarios ( 12.5%)
#
#   Usuarios en cluster 0:
#     - 3gerardpique              (Deportes)
#     - albertochicote            (TV, Series)
#     - Berto_Romero              (TV, Series)
#     - charliesheen              (Actor/Actriz)
#     - EdwardNorton              (Actor/Actriz)
#     - JohnKerry                 (Politica)
#     - perezreverte              (Escritores)
#     - XabiAlonso                (Deportes)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 1 (red) - Total usuarios: 13
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   3 usuarios ( 23.1%)
#   Cantante             (2):   5 usuarios ( 38.5%)
#   Modelo               (3):   2 usuarios ( 15.4%)
#   TV, Series           (4):   2 usuarios ( 15.4%)
#   Deportes             (7):   1 usuarios (  7.7%)
#
#   Usuarios en cluster 1:
#     - aplusk                    (Actor/Actriz)
#     - CourteneyCox              (Actor/Actriz)
#     - Cristiano                 (Deportes)
#     - EvaLongoria               (Modelo)
#     - gwenstefani               (Cantante)
#     - HilaryDuff                (Cantante)
#     - IamStevenT                (Cantante)
#     - IanMcKellen               (Actor/Actriz)
#     - JessieJ                   (Cantante)
#     - JLo                       (Cantante)
#     - JudgeJudy                 (TV, Series)
#     - Oprah                     (TV, Series)
#     - victoriabeckham           (Modelo)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 2 (green) - Total usuarios: 17
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   4 usuarios ( 23.5%)
#   Cantante             (2):   7 usuarios ( 41.2%)
#   Modelo               (3):   3 usuarios ( 17.6%)
#   TV, Series           (4):   2 usuarios ( 11.8%)
#   Tecnologia           (6):   1 usuarios (  5.9%)
#
#   Usuarios en cluster 2:
#     - AngelAlessandra           (Modelo)
#     - BarRefaeli                (Modelo)
#     - britneyspears             (Cantante)
#     - carmenelectra             (Modelo)
#     - Courtney                  (Cantante)
#     - epunset                   (Tecnologia)
#     - Fergie                    (Cantante)
#     - jimmyfallon               (TV, Series)
#     - justdemi                  (Actor/Actriz)
#     - kanyewest                 (Cantante)
#     - LeoDiCaprio               (Actor/Actriz)
#     - MariahCarey               (Cantante)
#     - shakira                   (Cantante)
#     - taylorswift13             (Cantante)
#     - TheEllenShow              (TV, Series)
#     - TheReal_Jlh               (Actor/Actriz)
#     - TomCruise                 (Actor/Actriz)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 3 (cyan) - Total usuarios: 6
# ────────────────────────────────────────────────────────────────────────────────
#   Cantante             (2):   1 usuarios ( 16.7%)
#   TV, Series           (4):   3 usuarios ( 50.0%)
#   Radio                (5):   1 usuarios ( 16.7%)
#   Deportes             (7):   1 usuarios ( 16.7%)
#
#   Usuarios en cluster 3:
#     - andykusnetzoff            (Radio)
#     - CristiPedroche            (TV, Series)
#     - davidbisbal               (Cantante)
#     - FALCAO                    (Deportes)
#     - jordiGlez                 (TV, Series)
#     - NadalMiki                 (TV, Series)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 4 (yellow) - Total usuarios: 3
# ────────────────────────────────────────────────────────────────────────────────
#   Deportes             (7):   2 usuarios ( 66.7%)
#   Politica             (8):   1 usuarios ( 33.3%)
#
#   Usuarios en cluster 4:
#     - Clyburn                   (Politica)
#     - RafaelNadal               (Deportes)
#     - usainbolt                 (Deportes)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 5 (orange) - Total usuarios: 3
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   1 usuarios ( 33.3%)
#   Politica             (8):   2 usuarios ( 66.7%)
#
#   Usuarios en cluster 5:
#     - jessicaalba               (Actor/Actriz)
#     - jiminhofe                 (Politica)
#     - Rep_Hunter                (Politica)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 6 (black) - Total usuarios: 5
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   1 usuarios ( 20.0%)
#   Cantante             (2):   4 usuarios ( 80.0%)
#
#   Usuarios en cluster 6:
#     - foofighters               (Cantante)
#     - JerrySeinfeld             (Actor/Actriz)
#     - OfficialAdele             (Cantante)
#     - rihanna                   (Cantante)
#     - xoellopez                 (Cantante)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 7 (pink) - Total usuarios: 13
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   3 usuarios ( 23.1%)
#   Cantante             (2):   3 usuarios ( 23.1%)
#   Modelo               (3):   1 usuarios (  7.7%)
#   Tecnologia           (6):   1 usuarios (  7.7%)
#   Deportes             (7):   2 usuarios ( 15.4%)
#   Politica             (8):   2 usuarios ( 15.4%)
#   Escritores           (9):   1 usuarios (  7.7%)
#
#   Usuarios en cluster 7:
#     - andyroddick               (Deportes)
#     - celinedion                (Cantante)
#     - heidiklum                 (Modelo)
#     - HillaryClinton            (Politica)
#     - jimlangevin               (Politica)
#     - jtimberlake               (Cantante)
#     - KevinSpacey               (Actor/Actriz)
#     - kobebryant                (Deportes)
#     - LennyKravitz              (Cantante)
#     - martinvars                (Tecnologia)
#     - paulocoelho               (Escritores)
#     - SJP                       (Actor/Actriz)
#     - tomhanks                  (Actor/Actriz)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 8 (brown) - Total usuarios: 8
# ────────────────────────────────────────────────────────────────────────────────
#   Cantante             (2):   4 usuarios ( 50.0%)
#   TV, Series           (4):   3 usuarios ( 37.5%)
#   Escritores           (9):   1 usuarios ( 12.5%)
#
#   Usuarios en cluster 8:
#     - AlejandroSanz             (Cantante)
#     - ChristianG_7              (TV, Series)
#     - David_Busta               (Cantante)
#     - drexlerjorge              (Cantante)
#     - JesusCalleja              (TV, Series)
#     - pabloalboran              (Cantante)
#     - porliniers                (Escritores)
#     - ristomejide               (TV, Series)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 9 (purple) - Total usuarios: 9
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   2 usuarios ( 22.2%)
#   TV, Series           (4):   2 usuarios ( 22.2%)
#   Radio                (5):   2 usuarios ( 22.2%)
#   Deportes             (7):   2 usuarios ( 22.2%)
#   Escritores           (9):   1 usuarios ( 11.1%)
#
#   Usuarios en cluster 9:
#     - Buenafuente               (TV, Series)
#     - CasillasWorld             (Deportes)
#     - DaniMateoAgain            (Radio)
#     - eva_hache                 (Actor/Actriz)
#     - josjaviersantos           (Escritores)
#     - JPVarsky                  (Radio)
#     - manuginobili              (Deportes)
#     - XaviRodriguez             (TV, Series)
#     - _josecoronado_            (Actor/Actriz)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 10 (magenta) - Total usuarios: 11
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   1 usuarios (  9.1%)
#   Cantante             (2):   2 usuarios ( 18.2%)
#   TV, Series           (4):   3 usuarios ( 27.3%)
#   Tecnologia           (6):   1 usuarios (  9.1%)
#   Deportes             (7):   2 usuarios ( 18.2%)
#   Politica             (8):   2 usuarios ( 18.2%)
#
#   Usuarios en cluster 10:
#     - alfredocasero1            (TV, Series)
#     - alo_oficial               (Deportes)
#     - andresiniesta8            (Deportes)
#     - CarlosAuryn               (Cantante)
#     - CFKArgentina              (Politica)
#     - DANIROVIRA                (Actor/Actriz)
#     - fieritacatalano           (Tecnologia)
#     - jordievole                (TV, Series)
#     - maria_patino              (TV, Series)
#     - pnique                    (Politica)
#     - SerranoIsmael             (Cantante)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 11 (lime) - Total usuarios: 3
# ────────────────────────────────────────────────────────────────────────────────
#   Deportes             (7):   1 usuarios ( 33.3%)
#   Politica             (8):   2 usuarios ( 66.7%)
#
#   Usuarios en cluster 11:
#     - andy_murray               (Deportes)
#     - GeorgeHWBush              (Politica)
#     - HerreraBeutler            (Politica)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 12 (teal) - Total usuarios: 6
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   2 usuarios ( 33.3%)
#   Cantante             (2):   4 usuarios ( 66.7%)
#
#   Usuarios en cluster 12:
#     - EmWatson                  (Actor/Actriz)
#     - enrique305                (Cantante)
#     - katyperry                 (Cantante)
#     - KidRock                   (Cantante)
#     - MeganFox516               (Actor/Actriz)
#     - springsteen               (Cantante)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 13 (navy) - Total usuarios: 18
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   2 usuarios ( 11.1%)
#   Modelo               (3):   1 usuarios (  5.6%)
#   TV, Series           (4):   1 usuarios (  5.6%)
#   Tecnologia           (6):   4 usuarios ( 22.2%)
#   Deportes             (7):   3 usuarios ( 16.7%)
#   Politica             (8):   5 usuarios ( 27.8%)
#   Escritores           (9):   2 usuarios ( 11.1%)
#
#   Usuarios en cluster 13:
#     - antoniobanderas           (Actor/Actriz)
#     - BarackObama               (Politica)
#     - BillGates                 (Tecnologia)
#     - DidacLee                  (Tecnologia)
#     - edans                     (Tecnologia)
#     - FernandezAnibal           (Politica)
#     - hughlaurie                (TV, Series)
#     - ierrejon                  (Politica)
#     - iescolar                  (Escritores)
#     - JesusEncinar              (Tecnologia)
#     - jk_rowling                (Escritores)
#     - KAKA                      (Deportes)
#     - KateUpton                 (Modelo)
#     - lorenzo99                 (Deportes)
#     - Pablo_Iglesias_           (Politica)
#     - paugasol                  (Deportes)
#     - RealHughJackman           (Actor/Actriz)
#     - sanchezcastejon           (Politica)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 14 (maroon) - Total usuarios: 3
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   1 usuarios ( 33.3%)
#   Modelo               (3):   1 usuarios ( 33.3%)
#   Tecnologia           (6):   1 usuarios ( 33.3%)
#
#   Usuarios en cluster 14:
#     - Carrie_Br4dshaw           (Modelo)
#     - SSantiagosegura           (Actor/Actriz)
#     - stevewoz                  (Tecnologia)
#
# ────────────────────────────────────────────────────────────────────────────────
# Cluster 15 (olive) - Total usuarios: 14
# ────────────────────────────────────────────────────────────────────────────────
#   Actor/Actriz         (1):   5 usuarios ( 35.7%)
#   Cantante             (2):   4 usuarios ( 28.6%)
#   Modelo               (3):   1 usuarios (  7.1%)
#   TV, Series           (4):   1 usuarios (  7.1%)
#   Radio                (5):   1 usuarios (  7.1%)
#   Deportes             (7):   1 usuarios (  7.1%)
#   Politica             (8):   1 usuarios (  7.1%)
#
#   Usuarios en cluster 15:
#     - aguerosergiokun           (Deportes)
#     - AvrilLavigne              (Cantante)
#     - cesarmillan               (TV, Series)
#     - CindyCrawford             (Modelo)
#     - Diane_Keaton              (Actor/Actriz)
#     - GwynethPaltrow            (Actor/Actriz)
#     - justinbieber              (Cantante)
#     - ladygaga                  (Cantante)
#     - MelanieGriffith           (Actor/Actriz)
#     - MileyCyrus                (Actor/Actriz)
#     - PaulaMeliveo              (Radio)
#     - SarahPalinUSA             (Politica)
#     - thelittleidiot            (Cantante)
#     - ZacEfron                  (Actor/Actriz)

# %% [markdown]
# ### 11. Clasificación de un Dato Sintético
#
# Se clasifica un nuevo punto de datos (sintético) utilizando cada uno de los modelos K-Means entrenados, mostrando a qué cluster se asigna y las distancias a todos los centroides.

# %%
# x_new debe tener la misma cantidad de características que x_original (4 en este caso: OP, CO, EX, AG)
x_new_original_features = np.array([[45.92, 25.0, 57.74, 15.66]]) # Ejemplo con 4 valores originales

# Transformar x_new_original_features a las componentes principales usando el PCA ya ajustado
x_new_transformed = pca.transform(x_new_original_features)

print(f"\n{'='*80}")
print("CLASIFICACIÓN DE DATO SINTÉTICO")
print(f"{'='*80}\n")

# Imprimir los valores de las componentes principales del dato sintético
print(f"Valores de las Componentes Principales para el dato sintético: ")
for i in range(x_new_transformed.shape[1]):
    print(f"  {seleccionadas[i].upper()}={x_new_transformed[0,i]:.2f}")
print()

for name, km in models.items():
    cluster_asignado = km.predict(x_new_transformed)[0]
    distancias = pairwise_distances(x_new_transformed, km.cluster_centers_)[0]

    print(f"{name.upper()}: Cluster {cluster_asignado}")
    print(f"  Distancias a todos los centroides: {distancias}")
    print()
# Out:
# ================================================================================
# CLASIFICACIÓN DE DATO SINTÉTICO
# ================================================================================
#
# Valores de las Componentes Principales para el dato sintético:
#   PC1=-2.30
#   PC2=-7.71
#   PC3=16.63
#
# ELBOW: Cluster 1
#   Distancias a todos los centroides: [21.11574443 20.73890032]
#
# SILHOUETTE: Cluster 1
#   Distancias a todos los centroides: [21.11574443 20.73890032]
#
# CALINSKI: Cluster 1
#   Distancias a todos los centroides: [21.11574443 20.73890032]
#
# DAVIES: Cluster 2
#   Distancias a todos los centroides: [24.76181744 23.86251687 15.14343447 23.13357832 15.54451847 32.71099121
#  36.49570883 18.89841052 19.23219743 29.38034164 20.01945928 32.73613968
#  25.3987793  17.25900569 32.29960064 22.63604714]

# %% [markdown]
# ### 12. Métricas de Evaluación de los Modelos
#
# Se calculan y grafican diversas métricas de evaluación para cada modelo de clustering, incluyendo Accuracy, Precision, Recall, F1-Score, ROC-AUC y Matrices de Confusión. Es importante recordar que estas métricas de clasificación supervisada se usan aquí para evaluar la correspondencia entre los clusters encontrados y las categorías originales, no la calidad intrínseca del clustering no supervisado.

# %%
print(f"\n{'='*80}")
print("MÉTRICAS DE EVALUACIÓN POR MODELO")
print(f"{'='*80}\n")

y_true = y  # categorías reales

fig_roc, axes_roc = plt.subplots(2, 2, figsize=(16, 12))
axes_roc = axes_roc.ravel()

metricas_resultados = {}

for idx, (name, km) in enumerate(models.items()):
    print(f"\n{'─'*80}")
    print(f"MODELO: {name.upper()} (k={km.n_clusters})")
    print(f"{'─'*80}\n")

    # Predecir clusters
    y_pred = km.predict(x)

    # Calcular métricas de clasificación
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    print(f"  Accuracy:  {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall:    {recall:.4f}")
    print(f"  F1-Score:  {f1:.4f}")

    metricas_resultados[name] = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1
    }

    # Calcular y graficar ROC curve (One-vs-Rest)
    try:
        # Asegurarse de que y_true y y_pred tengan las mismas clases para binarizar
        unique_classes = np.unique(np.concatenate((y_true, y_pred)))
        y_bin = label_binarize(y_true, classes=unique_classes)
        y_pred_bin = label_binarize(y_pred, classes=unique_classes)

        if y_bin.shape[1] > 1:
            roc_auc = roc_auc_score(y_bin, y_pred_bin, average='weighted', multi_class='ovr')
            print(f"  ROC-AUC:   {roc_auc:.4f}\n")
            metricas_resultados[name]['roc_auc'] = roc_auc

            # Graficar ROC curve
            fpr = dict()
            tpr = dict()
            roc_auc_curve = dict()

            for class_id in unique_classes:
                y_true_class = (y_true == class_id).astype(int)
                y_pred_class = (y_pred == class_id).astype(int)
                if len(np.unique(y_true_class)) > 1 and len(np.unique(y_pred_class)) > 1:
                    fpr[class_id], tpr[class_id], _ = roc_curve(y_true_class, y_pred_class)
                    roc_auc_curve[class_id] = roc_auc_score(y_true_class, y_pred_class)

            if roc_auc_curve:
                # Plot para la primera clase válida encontrada
                first_class_id = list(roc_auc_curve.keys())[0]
                axes_roc[idx].plot(fpr[first_class_id], tpr[first_class_id], color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc_curve[first_class_id]:.3f})')
                axes_roc[idx].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random')
                axes_roc[idx].set_xlim([0.0, 1.0])
                axes_roc[idx].set_ylim([0.0, 1.05])
                axes_roc[idx].set_xlabel('False Positive Rate')
                axes_roc[idx].set_ylabel('True Positive Rate')
                axes_roc[idx].set_title(f'{name.upper()} - ROC Curve (k={km.n_clusters})')
                axes_roc[idx].legend(loc="lower right")
                axes_roc[idx].grid(alpha=0.3)
            else:
                print("  ROC Curve: No valid classes to plot.")
        else:
             print("  ROC-AUC:   No se puede calcular ROC-AUC con una sola clase.\n")

    except Exception as e:
        print(f"  ROC-AUC:   Error - {str(e)}\n")

plt.tight_layout()
plt.show()

# Matrices de confusión para cada modelo
print(f"\n{'='*80}")
print("MATRICES DE CONFUSIÓN")
print(f"{'='*80}\n")

fig_cm, axes_cm = plt.subplots(2, 2, figsize=(16, 12))
axes_cm = axes_cm.ravel()

for idx, (name, km) in enumerate(models.items()):
    y_pred = km.predict(x)

    # Calcular matriz de confusión
    cm = confusion_matrix(y_true, y_pred)

    # Graficar heatmap
    sb.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes_cm[idx], cbar=True)
    axes_cm[idx].set_title(f'{name.upper()} - Confusion Matrix (k={km.n_clusters})')
    axes_cm[idx].set_xlabel('Clusters Predichos')
    axes_cm[idx].set_ylabel('Categorías Reales')

plt.tight_layout()
plt.show()

# Resumen comparativo
print(f"\n{'='*80}")
print("RESUMEN COMPARATIVO DE MÉTRICAS")
print(f"{'='*80}\n")

df_metricas = pd.DataFrame(metricas_resultados).T
print(df_metricas.to_string())
# Out:
# ================================================================================
# MÉTRICAS DE EVALUACIÓN POR MODELO
# ================================================================================
#
#
# ────────────────────────────────────────────────────────────────────────────────
# MODELO: ELBOW (k=2)
# ────────────────────────────────────────────────────────────────────────────────
#
#   Accuracy:  0.1571
#   Precision: 0.0517
#   Recall:    0.1571
#   F1-Score:  0.0779
#   ROC-AUC:   0.5274
#
#
# ────────────────────────────────────────────────────────────────────────────────
# MODELO: SILHOUETTE (k=2)
# ────────────────────────────────────────────────────────────────────────────────
#
#   Accuracy:  0.1571
#   Precision: 0.0517
#   Recall:    0.1571
#   F1-Score:  0.0779
#   ROC-AUC:   0.5274
#
#
# ────────────────────────────────────────────────────────────────────────────────
# MODELO: CALINSKI (k=2)
# ────────────────────────────────────────────────────────────────────────────────
#
#   Accuracy:  0.1571
#   Precision: 0.0517
#   Recall:    0.1571
#   F1-Score:  0.0779
#   ROC-AUC:   0.5274
#
#
# ────────────────────────────────────────────────────────────────────────────────
# MODELO: DAVIES (k=16)
# ────────────────────────────────────────────────────────────────────────────────
#
#   Accuracy:  0.0929
#   Precision: 0.1679
#   Recall:    0.0929
#   F1-Score:  0.1175
#   ROC-AUC:   0.5115
# ================================================================================
# MATRICES DE CONFUSIÓN
# ================================================================================
# ================================================================================
# RESUMEN COMPARATIVO DE MÉTRICAS
# ================================================================================
#
#             accuracy  precision    recall        f1   roc_auc
# elbow       0.157143   0.051742  0.157143  0.077851  0.527370
# silhouette  0.157143   0.051742  0.157143  0.077851  0.527370
# calinski    0.157143   0.051742  0.157143  0.077851  0.527370
# davies      0.092857   0.167949  0.092857  0.117500  0.511492

# %% [markdown]
# ## Revisar el contenido del cuaderno
#
# ### Subtarea: El usuario debe revisar las celdas ya ejecutadas en el cuaderno para ver el código, los resultados de la ejecución y las explicaciones del análisis de agrupamiento. El error `FileNotFoundError` se resolvió y el análisis se completó correctamente.

# %% [markdown]
# #### Instrucciones
# 1. Desplácese por el cuaderno para examinar todas las celdas ejecutadas.
#
# 2. Preste mucha atención al código utilizado para el análisis de agrupamiento.
#
# 3. Revise la salida y los resultados generados por la ejecución del código de agrupamiento.
#
# 4. Lea las explicaciones o interpretaciones del análisis de agrupamiento que se incluyen en el cuaderno.

# %% [markdown]
# ## Tarea final
#
# ### Subtarea: Confirmar que el usuario ha revisado correctamente el contenido del cuaderno y que se han satisfecho todos los aspectos de su solicitud de código, ejecución y explicaciones.

# %% [markdown]
# ## Resumen:
#
# ### Hallazgos clave del análisis de datos
# * Se agregó correctamente un bloque de Markdown con instrucciones detalladas para revisar el cuaderno.
#
# * Estas instrucciones guiaron al usuario en el examen del código, los resultados de ejecución y las explicaciones del análisis de agrupamiento.
#
# * Se resolvió el error `FileNotFoundError` que se había producido anteriormente y el análisis de agrupamiento se completó correctamente.
#
# * La subtarea de confirmar la revisión se consideró completada al proporcionar estas instrucciones para la revisión del usuario.
#
# ### Información adicional o próximos pasos
# * El usuario debe seguir las instrucciones proporcionadas para revisar exhaustivamente el análisis de agrupamiento, incluyendo su código, ejecución y explicaciones.
#
# * El sistema configuró correctamente el siguiente paso para que el usuario interactúe con el análisis completado.
